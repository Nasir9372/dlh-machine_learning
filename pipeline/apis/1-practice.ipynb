# %% [markdown]
# Connected to Python 3.9.25

# %%
#!/usr/bin/env python3
"""
This module creates a method that returns the list of
names of the home planets of all sentient species.
"""
import requests


def sentientPlanets():
    """
    Returns the list of names of the home
    planets of all sentient species.
    """
    planets = []
    url = "https://swapi-api.hbtn.io/api/species/"

    while url:

        response = requests.get(url)

        data = response.json()

        species_list = data["results"]

        for species in species_list:
            classification = (species["classification"]).lower()
            designation = (species["designation"]).lower()

            if (classification == "sentient" or designation == "sentient"):
                homeworld_url = species["homeworld"]

                if homeworld_url:
                    planet_response = requests.get(homeworld_url)
                    planet_data = planet_response.json()
                    planets.append(planet_data["name"])

        url = data["next"]

    return planets

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
print(data.keys())
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
print(data["count"])
# Out:
# 37

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
print(len(data))
# Out:
# 4

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
print(data["results"])
# Out:
# [{'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}, {'name': 'Droid', 'classification': 'artificial', 'designation': 'sentient', 'average_height': 'n/a', 'skin_colors': 'n/a', 'hair_colors': 'n/a', 'eye_colors': 'n/a', 'average_lifespan': 'indefinite', 'homeworld': None, 'language': 'n/a', 'people': ['https://swapi-api.hbtn.io/api/people/2/', 'https://swapi-api.hbtn.io/api/people/3/', 'https://swapi-api.hbtn.io/api/people/8/', 'https://swapi-api.hbtn.io/api/people/23/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T15:16:16.259000Z', 'edited': '2014-12-20T21:36:42.139000Z', 'url': 'https://swapi-api.hbtn.io/api/species/2/'}, {'name': 'Wookiee', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '210', 'skin_colors': 'gray', 'hair_colors': 'black, brown', 'eye_colors': 'blue, green, yellow, brown, golden, red', 'average_lifespan': '400', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/14/', 'language': 'Shyriiwook', 'people': ['https://swapi-api.hbtn.io/api/people/13/', 'https://swapi-api.hbtn.io/api/people/80/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T16:44:31.486000Z', 'edited': '2014-12-20T21:36:42.142000Z', 'url': 'https://swapi-api.hbtn.io/api/species/3/'}, {'name' ...

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
print(data["results"][0])
# Out:
# {'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
print(response.json()["results"])
# Out:
# [{'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}, {'name': 'Droid', 'classification': 'artificial', 'designation': 'sentient', 'average_height': 'n/a', 'skin_colors': 'n/a', 'hair_colors': 'n/a', 'eye_colors': 'n/a', 'average_lifespan': 'indefinite', 'homeworld': None, 'language': 'n/a', 'people': ['https://swapi-api.hbtn.io/api/people/2/', 'https://swapi-api.hbtn.io/api/people/3/', 'https://swapi-api.hbtn.io/api/people/8/', 'https://swapi-api.hbtn.io/api/people/23/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T15:16:16.259000Z', 'edited': '2014-12-20T21:36:42.139000Z', 'url': 'https://swapi-api.hbtn.io/api/species/2/'}, {'name': 'Wookiee', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '210', 'skin_colors': 'gray', 'hair_colors': 'black, brown', 'eye_colors': 'blue, green, yellow, brown, golden, red', 'average_lifespan': '400', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/14/', 'language': 'Shyriiwook', 'people': ['https://swapi-api.hbtn.io/api/people/13/', 'https://swapi-api.hbtn.io/api/people/80/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T16:44:31.486000Z', 'edited': '2014-12-20T21:36:42.142000Z', 'url': 'https://swapi-api.hbtn.io/api/species/3/'}, {'name' ...

# %%
import requests
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
species_list = data["results"]
print(species_list)
# Out:
# [{'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}, {'name': 'Droid', 'classification': 'artificial', 'designation': 'sentient', 'average_height': 'n/a', 'skin_colors': 'n/a', 'hair_colors': 'n/a', 'eye_colors': 'n/a', 'average_lifespan': 'indefinite', 'homeworld': None, 'language': 'n/a', 'people': ['https://swapi-api.hbtn.io/api/people/2/', 'https://swapi-api.hbtn.io/api/people/3/', 'https://swapi-api.hbtn.io/api/people/8/', 'https://swapi-api.hbtn.io/api/people/23/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T15:16:16.259000Z', 'edited': '2014-12-20T21:36:42.139000Z', 'url': 'https://swapi-api.hbtn.io/api/species/2/'}, {'name': 'Wookiee', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '210', 'skin_colors': 'gray', 'hair_colors': 'black, brown', 'eye_colors': 'blue, green, yellow, brown, golden, red', 'average_lifespan': '400', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/14/', 'language': 'Shyriiwook', 'people': ['https://swapi-api.hbtn.io/api/people/13/', 'https://swapi-api.hbtn.io/api/people/80/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T16:44:31.486000Z', 'edited': '2014-12-20T21:36:42.142000Z', 'url': 'https://swapi-api.hbtn.io/api/species/3/'}, {'name' ...

# %%
import requests
home_planet = []
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
species_list = data["results"]
for spec in species_list:
    if classification == "sentient" or designation == "sentient":
        home_planet.append(spec)
print(home_planet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       6 species_list = data["results"]
#       7 for spec in species_list:
# ----> 8     if classification == "sentient" or designation == "sentient":
#       9         home_planet.append(spec)
#      10 print(home_planet)
#
# NameError: name 'classification' is not defined

# %%
import requests
home_planet = []
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
species_list = data["results"]
for spec in species_list:
    classification = spec["classification"]
    designation = spec["designation"]
    if classification == "sentient" or designation == "sentient":
        home_planet.append(spec)
print(home_planet)
# Out:
# [{'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}, {'name': 'Droid', 'classification': 'artificial', 'designation': 'sentient', 'average_height': 'n/a', 'skin_colors': 'n/a', 'hair_colors': 'n/a', 'eye_colors': 'n/a', 'average_lifespan': 'indefinite', 'homeworld': None, 'language': 'n/a', 'people': ['https://swapi-api.hbtn.io/api/people/2/', 'https://swapi-api.hbtn.io/api/people/3/', 'https://swapi-api.hbtn.io/api/people/8/', 'https://swapi-api.hbtn.io/api/people/23/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T15:16:16.259000Z', 'edited': '2014-12-20T21:36:42.139000Z', 'url': 'https://swapi-api.hbtn.io/api/species/2/'}, {'name': 'Wookiee', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '210', 'skin_colors': 'gray', 'hair_colors': 'black, brown', 'eye_colors': 'blue, green, yellow, brown, golden, red', 'average_lifespan': '400', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/14/', 'language': 'Shyriiwook', 'people': ['https://swapi-api.hbtn.io/api/people/13/', 'https://swapi-api.hbtn.io/api/people/80/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T16:44:31.486000Z', 'edited': '2014-12-20T21:36:42.142000Z', 'url': 'https://swapi-api.hbtn.io/api/species/3/'}, {'name' ...

# %%
import requests
home_planet = []
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
species_list = data["results"]
for spec in species_list:
    classification = spec["classification"]
    designation = spec["designation"]
    if classification == "sentient" or designation == "sentient":
        home_planet.append(spec)
print(home_planet["name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 12
#      10     if classification == "sentient" or designation == "sentient":
#      11         home_planet.append(spec)
# ---> 12 print(home_planet["name"])
#
# TypeError: list indices must be integers or slices, not str

# %%
import requests
home_planet = []
url = "https://swapi-api.hbtn.io/api/species/"
response = requests.get(url)
data = response.json()
species_list = data["results"]
for spec in species_list:
    classification = spec["classification"]
    designation = spec["designation"]
    if classification == "sentient" or designation == "sentient":
        home_planet.append(spec)
for name in home_planet:
    print(name)
# Out:
# {'name': 'Human', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'caucasian, black, asian, hispanic', 'hair_colors': 'blonde, brown, black, red', 'eye_colors': 'brown, blue, green, hazel, grey, amber', 'average_lifespan': '120', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/9/', 'language': 'Galactic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/1/', 'https://swapi-api.hbtn.io/api/people/4/', 'https://swapi-api.hbtn.io/api/people/5/', 'https://swapi-api.hbtn.io/api/people/6/', 'https://swapi-api.hbtn.io/api/people/7/', 'https://swapi-api.hbtn.io/api/people/9/', 'https://swapi-api.hbtn.io/api/people/10/', 'https://swapi-api.hbtn.io/api/people/11/', 'https://swapi-api.hbtn.io/api/people/12/', 'https://swapi-api.hbtn.io/api/people/14/', 'https://swapi-api.hbtn.io/api/people/18/', 'https://swapi-api.hbtn.io/api/people/21/', 'https://swapi-api.hbtn.io/api/people/22/', 'https://swapi-api.hbtn.io/api/people/25/', 'https://swapi-api.hbtn.io/api/people/26/', 'https://swapi-api.hbtn.io/api/people/28/', 'https://swapi-api.hbtn.io/api/people/29/', 'https://swapi-api.hbtn.io/api/people/32/', 'https://swapi-api.hbtn.io/api/people/34/', 'https://swapi-api.hbtn.io/api/people/35/', 'https://swapi-api.hbtn.io/api/people/39/', 'https://swapi-api.hbtn.io/api/people/42/', 'https://swapi-api.hbtn.io/api/people/43/', 'https://swapi-api.hbtn.io/api/people/51/', 'https://swapi-api.hbtn.io/api/people/62/', 'https://swapi-api.hbtn.io/api/people/66/', 'https://swapi-api.hbtn.io/api/people/67/', 'https://swapi-api.hbtn.io/api/people/68/', 'https://swapi-api.hbtn.io/api/people/69/', 'https://swapi-api.hbtn.io/api/people/74/', 'https://swapi-api.hbtn.io/api/people/81/', 'https://swapi-api.hbtn.io/api/people/84/', 'https://swapi-api.hbtn.io/api/people/85/', 'https://swapi-api.hbtn.io/api/people/86/', 'https://swapi-api.hbtn.io/api/people/88/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T13:52:11.567000Z', 'edited': '2014-12-20T21:36:42.136000Z', 'url': 'https://swapi-api.hbtn.io/api/species/1/'}
# {'name': 'Droid', 'classification': 'artificial', 'designation': 'sentient', 'average_height': 'n/a', 'skin_colors': 'n/a', 'hair_colors': 'n/a', 'eye_colors': 'n/a', 'average_lifespan': 'indefinite', 'homeworld': None, 'language': 'n/a', 'people': ['https://swapi-api.hbtn.io/api/people/2/', 'https://swapi-api.hbtn.io/api/people/3/', 'https://swapi-api.hbtn.io/api/people/8/', 'https://swapi-api.hbtn.io/api/people/23/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T15:16:16.259000Z', 'edited': '2014-12-20T21:36:42.139000Z', 'url': 'https://swapi-api.hbtn.io/api/species/2/'}
# {'name': 'Wookiee', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '210', 'skin_colors': 'gray', 'hair_colors': 'black, brown', 'eye_colors': 'blue, green, yellow, brown, golden, red', 'average_lifespan': '400', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/14/', 'language': 'Shyriiwook', 'people': ['https://swapi-api.hbtn.io/api/people/13/', 'https://swapi-api.hbtn.io/api/people/80/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/6/', 'https://swapi-api.hbtn.io/api/films/7/'], 'created': '2014-12-10T16:44:31.486000Z', 'edited': '2014-12-20T21:36:42.142000Z', 'url': 'https://swapi-api.hbtn.io/api/species/3/'}
# {'name': 'Rodian', 'classification': 'sentient', 'designation': 'reptilian', 'average_height': '170', 'skin_colors': 'green, blue', 'hair_colors': 'n/a', 'eye_colors': 'black', 'average_lifespan': 'unknown', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/23/', 'language': 'Galatic Basic', 'people': ['https://swapi-api.hbtn.io/api/people/15/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/'], 'created': '2014-12-10T17:05:26.471000Z', 'edited': '2014-12-20T21:36:42.144000Z', 'url': 'https://swapi-api.hbtn.io/api/species/4/'}
# {'name': 'Hutt', 'classification': 'gastropod', 'designation': 'sentient', 'average_height': '300', 'skin_colors': 'green, brown, tan', 'hair_colors': 'n/a', 'eye_colors': 'yellow, red', 'average_lifespan': '1000', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/24/', 'language': 'Huttese', 'people': ['https://swapi-api.hbtn.io/api/people/16/'], 'films': ['https://swapi-api.hbtn.io/api/films/1/', 'https://swapi-api.hbtn.io/api/films/3/'], 'created': '2014-12-10T17:12:50.410000Z', 'edited': '2014-12-20T21:36:42.146000Z', 'url': 'https://swapi-api.hbtn.io/api/species/5/'}
# {'name': "Yoda's species", 'classification': 'mammal', 'designation': 'sentient', 'average_height': '66', 'skin_colors': 'green, yellow', 'hair_colors': 'brown, white', 'eye_colors': 'brown, green, yellow', 'average_lifespan': '900', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/28/', 'language': 'Galactic basic', 'people': ['https://swapi-api.hbtn.io/api/people/20/'], 'films': ['https://swapi-api.hbtn.io/api/films/2/', 'https://swapi-api.hbtn.io/api/films/3/', 'https://swapi-api.hbtn.io/api/films/4/', 'https://swapi-api.hbtn.io/api/films/5/', 'https://swapi-api.hbtn.io/api/films/6/'], 'created': '2014-12-15T12:27:22.877000Z', 'edited': '2014-12-20T21:36:42.148000Z', 'url': 'https://swapi-api.hbtn.io/api/species/6/'}
# {'name': 'Trandoshan', 'classification': 'reptile', 'designation': 'sentient', 'average_height': '200', 'skin_colors': 'brown, green', 'hair_colors': 'none', 'eye_colors': 'yellow, orange', 'average_lifespan': 'unknown', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/29/', 'language': 'Dosh', 'people': ['https://swapi-api.hbtn.io/api/people/24/'], 'films': ['https://swapi-api.hbtn.io/api/films/2/'], 'created': '2014-12-15T13:07:47.704000Z', 'edited': '2014-12-20T21:36:42.151000Z', 'url': 'https://swapi-api.hbtn.io/api/species/7/'}
# {'name': 'Mon Calamari', 'classification': 'amphibian', 'designation': 'sentient', 'average_height': '160', 'skin_colors': 'red, blue, brown, magenta', 'hair_colors': 'none', 'eye_colors': 'yellow', 'average_lifespan': 'unknown', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/31/', 'language': 'Mon Calamarian', 'people': ['https://swapi-api.hbtn.io/api/people/27/'], 'films': ['https://swapi-api.hbtn.io/api/films/3/'], 'created': '2014-12-18T11:09:52.263000Z', 'edited': '2014-12-20T21:36:42.153000Z', 'url': 'https://swapi-api.hbtn.io/api/species/8/'}
# {'name': 'Ewok', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '100', 'skin_colors': 'brown', 'hair_colors': 'white, brown, black', 'eye_colors': 'orange, brown', 'average_lifespan': 'unknown', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/7/', 'language': 'Ewokese', 'people': ['https://swapi-api.hbtn.io/api/people/30/'], 'films': ['https://swapi-api.hbtn.io/api/films/3/'], 'created': '2014-12-18T11:22:00.285000Z', 'edited': '2014-12-20T21:36:42.155000Z', 'url': 'https://swapi-api.hbtn.io/api/species/9/'}
# {'name': 'Sullustan', 'classification': 'mammal', 'designation': 'sentient', 'average_height': '180', 'skin_colors': 'pale', 'hair_colors': 'none', 'eye_colors': 'black', 'average_lifespan': 'unknown', 'homeworld': 'https://swapi-api.hbtn.io/api/planets/33/', 'language': 'Sullutese', 'people': ['https://swapi-api.hbtn.io/api/people/31/'], 'films': ['https://swapi-api.hbtn.io/api/films/3/'], 'created': '2014-12-18T11:26:20.103000Z', 'edited': '2014-12-20T21:36:42.157000Z', 'url': 'https://swapi-api.hbtn.io/api/species/10/'}

# %%
import requests

def sentientPlanets():
    home_planets = []
    url = "https://swapi-api.hbtn.io/api/species/"
    
    while url:
        response = requests.get(url)
        data = response.json()
        species_list = data["results"]
        
        for spec in species_list:
            classification = spec.get("classification", "").lower()
            designation = spec.get("designation", "").lower()
            
            if "sentient" in classification or "sentient" in designation:
                planet_url = spec.get("homeworld")
                if planet_url:
                    # Fetch planet name from the planet URL
                    planet_response = requests.get(planet_url)
                    planet_data = planet_response.json()
                    home_planets.append(planet_data.get("name"))
        
        url = data.get("next")  # pagination
    
    return home_planets

planets = sentientPlanets()
for planet in planets:
    print(planet)
# Out:
# Coruscant
# Kashyyyk
# Rodia
# Nal Hutta
# unknown
# Trandosha
# Mon Cala
# Endor
# Sullust
# Cato Neimoidia
# Naboo
# Toydaria
# Malastare
# Ryloth
# Aleen Minor
# Vulpter
# Troiken
# Tund
# Cerea
# Glee Anselm
# Iridonia
# Tholoth
# Iktotch
# Quermia
# Dorin
# Champala
# Geonosis
# Mirial
# Zolan
# Ojom
# Kamino
# Skako
# Muunilinst
# Shili
# Kalee
# Utapau
